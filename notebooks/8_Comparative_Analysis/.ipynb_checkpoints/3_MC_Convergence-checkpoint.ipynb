# %% [markdown]
# #  Monte Carlo Convergence & Performance Analysis
# This notebook evaluates the convergence and runtime performance of the Monte Carlo pricer by varying the number of simulation paths.

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import os, sys

sys.path.append(os.path.abspath("../../"))

from pricing.bsm import black_scholes_price
from pricing.monte_carlo import MonteCarloPricer

# %%
# Option and model parameters
S0 = 100
K = 100
T = 1.0
r = 0.05
sigma = 0.2
option_type = 'call'

# %%
# Simulation sizes to test
n_paths_list = [1000, 5000, 10000, 50000, 100000]

mc_prices = []
mc_times = []
errors = []

# Reference price using BSM
ref_price = black_scholes_price(S0, K, T, r, sigma, option_type=option_type)

for n_paths in n_paths_list:
    mc = MonteCarloPricer(S0=S0, K=K, T=T, r=r, sigma=sigma, n_paths=n_paths, option_type=option_type)

    start = time.time()
    price = mc.price_european_option()
    t = time.time() - start

    mc_prices.append(price)
    mc_times.append(t)
    errors.append(abs(price - ref_price))

# %% [markdown]
# ## 📈 Performance and Accuracy
# We now plot the runtime and error of Monte Carlo pricing against the number of simulation paths.

# %%
plt.figure(figsize=(12, 5))

# Runtime vs paths
plt.subplot(1, 2, 1)
plt.plot(n_paths_list, mc_times, marker='o')
plt.title("MC Runtime vs Path Count")
plt.xlabel("Number of Paths")
plt.ylabel("Runtime (s)")

# Error vs paths
plt.subplot(1, 2, 2)
plt.plot(n_paths_list, errors, marker='o', color='red')
plt.title("MC Error vs Path Count")
plt.xlabel("Number of Paths")
plt.ylabel("Absolute Error vs BSM")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 🔍 Observations
#
# - Monte Carlo runtime increases linearly with the number of paths.
# - The pricing error decreases gradually, showing statistical convergence toward the BSM reference.
# - Compared to PDE, convergence is slower but easy to parallelize and extend to high dimensions.
